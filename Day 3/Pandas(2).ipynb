# %%
# 2. Go to kaggle.com. Create an account if you have not already. Download the `Gapminder World’
# Dataset after searching for it in Kaggle search.

# %%
# i) Load the dataset as a dataframe df using Pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('gapminder_full.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# ii) Verify using the type function that df is indeed a dataframe.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# iii) Print the size of df using the shape attribute.

# %%
df.shape
# Out:
# (1704, 6)

# %%
# Understand what each column means:

# %%
# iv) Print the column names using the columns attribute.

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
# v) Use dtypes attribute to get datatype of each column.

# %%
df.dtypes
# Out:
# country        object
# year            int64
# population      int64
# continent      object
# life_exp      float64
# gdp_cap       float64
# dtype: object

# %%
# vi) Get more information by simply using the info function.

# %%
df.info
# Out:
# <bound method DataFrame.info of           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
# vii) Get a feel of the actual data values by printing the first 20 rows of df using head function and
# the last 10 rows using the tail function.

# %%
df.head(20)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
# viii) Obtain unique values in each column by using the unique function and count their occurrence
# in a column using nunique function.

# %%
print(df['country'].unique())
print(df['country'].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'Angola' 'Argentina' 'Australia'
#  'Austria' 'Bahrain' 'Bangladesh' 'Belgium' 'Benin' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cambodia' 'Cameroon' 'Canada' 'Central African Republic'
#  'Chad' 'Chile' 'China' 'Colombia' 'Comoros' 'Congo, Dem. Rep.'
#  'Congo, Rep.' 'Costa Rica' "Cote d'Ivoire" 'Croatia' 'Cuba'
#  'Czech Republic' 'Denmark' 'Djibouti' 'Dominican Republic' 'Ecuador'
#  'Egypt' 'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Ethiopia' 'Finland'
#  'France' 'Gabon' 'Gambia' 'Germany' 'Ghana' 'Greece' 'Guatemala' 'Guinea'
#  'Guinea-Bissau' 'Haiti' 'Honduras' 'Hong Kong, China' 'Hungary' 'Iceland'
#  'India' 'Indonesia' 'Iran' 'Iraq' 'Ireland' 'Israel' 'Italy' 'Jamaica'
#  'Japan' 'Jordan' 'Kenya' 'Korea, Dem. Rep.' 'Korea, Rep.' 'Kuwait'
#  'Lebanon' 'Lesotho' 'Liberia' 'Libya' 'Madagascar' 'Malawi' 'Malaysia'
#  'Mali' 'Mauritania' 'Mauritius' 'Mexico' 'Mongolia' 'Montenegro'
# ...

# %%
print(df['year'].unique())
print(df['year'].nunique())
# Out:
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]
# 12

# %%
print(df['population'].unique())
print(df['population'].nunique())
# Out:
# [ 8425333  9240934 10267083 ... 11404948 11926563 12311143]
# 1704

# %%
print(df['continent'].unique())
print(df['continent'].nunique())
# Out:
# ['Asia' 'Europe' 'Africa' 'Americas' 'Oceania']
# 5

# %%
print(df['life_exp'].unique())
print(df['life_exp'].nunique())
# Out:
# [28.801 30.332 31.997 ... 46.809 39.989 43.487]
# 1626

# %%
print(df['gdp_cap'].unique())
print(df['gdp_cap'].nunique())
# Out:
# [779.4453145 820.8530296 853.10071   ... 792.4499603 672.0386227
#  469.7092981]
# 1704

# %%
# ix) Check if there are any missing data and NaN values in each column.

# %%
df['country'].isnull().values.any()
# Out:
# False

# %%
df['year'].isnull().values.any()
# Out:
# False

# %%
df['population'].isnull().values.any()
# Out:
# False

# %%
df['continent'].isnull().values.any()
# Out:
# False

# %%
df['life_exp'].isnull().values.any()
# Out:
# False

# %%
df['gdp_cap'].isnull().values.any()
# Out:
# False

# %%
# xi) Use describe function get summary statistics for the df.

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
# 3. i) Subset df by each continent and store these dataframes as dfasia, dfafrica, dfamericas, dfeurope and
#    dfoceania.

# %%
dfAsia = df[df['continent'] == 'Asia']
dfAsia
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1675  Yemen, Rep.  1987    11219340      Asia    52.922  1971.741538
# 1676  Yemen, Rep.  1992    13367997      Asia    55.599  1879.496673
# 1677  Yemen, Rep.  1997    15826497      Asia    58.020  2117.484526
# 1678  Yemen, Rep.  2002    18701257      Asia    60.308  2234.820827
# 1679  Yemen, Rep.  2007    22211743      Asia    62.698  2280.769906
#
# [396 rows x 6 columns]

# %%
dfAfrica = df[df['continent'] == 'Africa']

# %%
dfAmericas = df[df['continent'] == 'Americas']

# %%
dfEurope = df[df['continent'] == 'Europe']

# %%
dfocenia = df[df['continent'] == 'Oceania']

# %%
# ii) On each continent
#       a) Print the countries with highest and lowest life expectancy on the Asian continent that is 
#                    the dAsia dataframe.
#       b) Print the mean GDP per capita and mean population of these countries? Can you see a
#                    relation between these 2 variables for these countries.
#       c) In general, plot the time series on three separate plots for each of the two countries found above 
                        # population vs GDP per capita
                        # population vs life expectancy
                        # life expectancy vs GDP per capita?
#       Can you possibly hypothesize some relation between these three variables.

# %%
#       a) Print the countries with highest and lowest life expectancy on the Asian continent that is 
#                    the dasia dataframe.

# %%
dfAsia[ dfAsia['life_exp'] == dfAsia['life_exp'].max()]['country']
# Out:
# 803    Japan
# Name: country, dtype: object

# %%
dfAsia[ dfAsia['life_exp'] == dfAsia['life_exp'].min()]['country']
# Out:
# 0    Afghanistan
# Name: country, dtype: object

# %%
#      b) Print the mean GDP per capita and mean population of these countries? Can you see a
#                    relation between these 2 variables for these countries.

# %%
dfAsia[dfAsia['country'] == 'Japan']['gdp_cap'].mean()
# Out:
# 17750.869984166664

# %%
dfAsia[dfAsia['country'] == 'Afghanistan']['gdp_cap'].mean()
# Out:
# 802.674598425

# %%
#    c) In general, plot the time series on three separate plots for each of the two countries found above 
                        # population vs GDP per capita
                        # population vs life expectancy
                        # life expectancy vs GDP per capita?

# %%
plt.plot(dfAsia[dfAsia['country'] == 'Japan']['population'], dfAsia[dfAsia['country'] == 'Japan']['gdp_cap'] )

plt.show()

# %%
plt.plot(dfAsia[dfAsia['country'] == 'Japan']['population'], dfAsia[dfAsia['country'] == 'Japan']['life_exp'] )

plt.show()

# %%
plt.plot(dfAsia[dfAsia['country'] == 'Japan']['life_exp'], dfAsia[dfAsia['country'] == 'Japan']['gdp_cap'] )

plt.show()

# %%
plt.plot(dfAsia[dfAsia['country'] == 'Afghanistan']['population'], dfAsia[dfAsia['country'] == 'Afghanistan']['gdp_cap'] )

plt.show()

# %%
plt.plot(dfAsia[dfAsia['country'] == 'Afghanistan']['population'], dfAsia[dfAsia['country'] == 'Afghanistan']['life_exp'])

plt.show()

# %%
plt.plot(dfAsia[dfAsia['country'] == 'Afghanistan']['life_exp'], dfAsia[dfAsia['country'] == 'Afghanistan']['gdp_cap'] )

plt.show()

# %%
# 4. i) Compute statistics for the world for each year by grouping df by year. 
#    ii) Compute statistics country wise by grouping df by country.
#    iii) Compute statistics for the continent by grouping df by continent
#              a) What is the mean life expectancy for the world?
#              b) What was the mean life expectancy for the continents? Which continent comes close to
#                 mean life expectancy of the world?
#              c) Which countries come close to the mean life expectancy on their continents?
#              d) Which countries come close to the mean life expectancy of the world?

# %%
df.groupby('year').describe()
# Out:
#      population                                                                \
#           count          mean           std       min         25%         50%
# year
# 1952      142.0  1.695040e+07  5.810086e+07   60011.0  1452026.25   3943953.0
# 1957      142.0  1.876341e+07  6.550429e+07   61325.0  1568811.25   4282942.0
# 1962      142.0  2.042101e+07  6.978865e+07   65345.0  1784362.00   4686039.5
# 1967      142.0  2.265830e+07  7.837548e+07   70787.0  2034768.50   5170175.5
# 1972      142.0  2.518998e+07  8.864682e+07   76595.0  2351191.50   5877996.5
# 1977      142.0  2.767638e+07  9.748109e+07   86796.0  2759717.25   6404036.5
# 1982      142.0  3.020730e+07  1.050986e+08   98593.0  3006286.25   7007320.0
# 1987      142.0  3.303857e+07  1.147562e+08  110812.0  3194989.50   7774861.5
# 1992      142.0  3.599092e+07  1.245026e+08  125911.0  3605992.00   8688686.5
# 1997      142.0  3.883947e+07  1.334174e+08  145608.0  3770149.75   9735063.5
# ...

# %%
df.groupby('country').describe()
# Out:
#                     year                                                       \
#                    count    mean        std     min      25%     50%      75%
# country
# Afghanistan         12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# Albania             12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# Algeria             12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# Angola              12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# Argentina           12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# ...                  ...     ...        ...     ...      ...     ...      ...
# Vietnam             12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# West Bank and Gaza  12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# Yemen, Rep.         12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# Zambia              12.0  1979.5  18.027756  1952.0  1965.75  1979.5  1993.25
# ...

# %%
df.groupby('continent').describe()
# Out:
#             year                                                               \
#            count    mean        std     min      25%     50%      75%     max
# continent
# Africa     624.0  1979.5  17.274110  1952.0  1965.75  1979.5  1993.25  2007.0
# Americas   300.0  1979.5  17.289102  1952.0  1965.75  1979.5  1993.25  2007.0
# Asia       396.0  1979.5  17.282097  1952.0  1965.75  1979.5  1993.25  2007.0
# Europe     360.0  1979.5  17.284285  1952.0  1965.75  1979.5  1993.25  2007.0
# Oceania     24.0  1979.5  17.631494  1952.0  1965.75  1979.5  1993.25  2007.0
#
#           population                ...  life_exp         gdp_cap  \
#                count          mean  ...       75%     max   count
# continent                           ...
# Africa         624.0  9.916003e+06  ...  54.41150  76.442   624.0
# Americas       300.0  2.450479e+07  ...  71.69950  80.653   300.0
# Asia           396.0  7.703872e+07  ...  69.50525  82.603   396.0
# ...
